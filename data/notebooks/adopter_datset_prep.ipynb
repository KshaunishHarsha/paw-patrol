# %%
import pandas as pd
import numpy as np

columns = [
    "AdopterID",
    "activity_level",
    "home_type",
    "home_size",
    "pet_experience",
    "available_time",
    "kids_present",
    "other_pets",
    "pet_budget",
    "insurance_willing",
    "vet_commitment",
    "air_conditioning_available",
    "training_commitment",
    "patience_level",
    "grooming_tolerance",
    "noise_tolerance",
    "long_term_commitment"
]

adopters = pd.DataFrame(columns=columns)

# %%
n = 1000

adopters = pd.DataFrame({
    "AdopterID": [f"A{i}" for i in range(1, n+1)],
    "activity_level": np.random.choice(["low","medium","high"], n),
    "home_type": np.random.choice(["apartment","house"], n),
    "home_size": np.random.choice(["small","medium","large"], n),
    "pet_experience": np.random.choice(["beginner","intermediate","experienced"], n),
    "available_time": np.random.choice(["low","medium","high"], n),
    "kids_present": np.random.choice(["yes","no"], n),
    "other_pets": np.random.choice(["yes","no"], n),
    "pet_budget": np.random.choice(["low","medium","high"], n),
    "insurance_willing": np.random.choice(["yes","no"], n),
    "vet_commitment": np.random.choice(["low","medium","high"], n),
    "air_conditioning_available": np.random.choice(["yes","no"], n),
    "training_commitment": np.random.choice(["low","medium","high"], n),
    "patience_level": np.random.choice(["low","medium","high"], n),
    "grooming_tolerance": np.random.choice(["low","medium","high"], n),
    "noise_tolerance": np.random.choice(["low","medium","high"], n),
    "long_term_commitment": np.random.choice(["yes","no"], n)
})

# %%
adopters.head()
# Out:
#   AdopterID activity_level  home_type home_size pet_experience available_time  \
# 0        A1            low  apartment     small   intermediate           high
# 1        A2         medium  apartment     small       beginner            low
# 2        A3         medium      house     large   intermediate            low
# 3        A4           high  apartment    medium   intermediate         medium
# 4        A5            low  apartment     small   intermediate           high
#
#   kids_present other_pets pet_budget insurance_willing vet_commitment  \
# 0          yes         no       high                no            low
# 1           no        yes        low                no           high
# 2          yes         no     medium               yes         medium
# 3           no         no        low                no         medium
# 4          yes        yes       high               yes            low
#
#   air_conditioning_available training_commitment patience_level  \
# 0                        yes              medium           high
# 1                        yes                 low            low
# 2                         no              medium            low
# 3                        yes                 low           high
# 4                         no                 low            low
#
#   grooming_tolerance noise_tolerance long_term_commitment
# 0               high          medium                  yes
# 1               high             low                  yes
# 2                low             low                   no
# 3             medium             low                   no
# 4             medium             low                  yes

# %%
adopters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AdopterID                   1000 non-null   object
#  1   activity_level              1000 non-null   object
#  2   home_type                   1000 non-null   object
#  3   home_size                   1000 non-null   object
#  4   pet_experience              1000 non-null   object
#  5   available_time              1000 non-null   object
#  6   kids_present                1000 non-null   object
#  7   other_pets                  1000 non-null   object
#  8   pet_budget                  1000 non-null   object
#  9   insurance_willing           1000 non-null   object
#  10  vet_commitment              1000 non-null   object
#  11  air_conditioning_available  1000 non-null   object
#  12  training_commitment         1000 non-null   object
#  13  patience_level              1000 non-null   object
#  14  grooming_tolerance          1000 non-null   object
#  15  noise_tolerance             1000 non-null   object
#  16  long_term_commitment        1000 non-null   object
# dtypes: object(17)
# memory usage: 132.9+ KB

# %%
adopters.to_csv(r"C:\Users\kshau\paw-patrol\data\datasets\adopters_dataset.csv", index=False)
